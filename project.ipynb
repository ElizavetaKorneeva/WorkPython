# %%
import pandas as pd

# %%
table = pd.read_csv('C:/Users/Liza/Desktop/work/data1.csv', sep = ',')
table
# Out:
#    № строки Федеральные округа и субъекты Российской Федерации  \
# 0         А                                                  Б
# 1         1                                              ВСЕГО
# 2         2                  Дальневосточный федеральный округ
# 3         3                                   Амурская область
# 4         4                       Еврейская автономная область
# 5         5                                    Камчатский край
# 6         6                                Магаданская область
# 7         7                                    Приморский край
# 8         8                           Республика Саха (Якутия)
# 9         9                                Сахалинская область
# 10       10                                   Хабаровский край
# 11       11                         Чукотский автономный округ
# 12       12                      Приволжский федеральный округ
# 13       13                                  Кировская область
# ...

# %%
table = pd.read_csv('C:/Users/Liza/Desktop/work/data-20190704T1001-structure-20190704T1001.csv',sep = ',')
table
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-14-e87eac7bf2fb> in <module>
# ----> 1 table = pd.read_csv('C:/Users/Liza/Desktop/work/data-20190704T1001-structure-20190704T1001.csv',sep = ',')
#       2 table
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
